# %%
import numpy as np
import matplotlib.pyplot as plt
data = {'Java':22.2,'Python':17.6,'PHP':8.8,'JavaScript':8,'C#':7.7,'C++':6.7}
courses = list(data.keys())
values = list(data.values())
fig = plt.figure(figsize = (10,5))
plt.pie(courses,values)
plt.xlabel("Programming Languages")
plt.ylabel("Popularity")
plt.title("Popularity of Programming Languages")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10076/108167184.py in <module>
#       5 values = list(data.values())
#       6 fig = plt.figure(figsize = (10,5))
# ----> 7 plt.pie(courses,values)
#       8 plt.xlabel("Programming Languages")
#       9 plt.ylabel("Popularity")
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    3004         textprops=None, center=(0, 0), frame=False,
#    3005         rotatelabels=False, *, normalize=None, data=None):
# -> 3006     return gca().pie(
#    3007         x, explode=explode, labels=labels, colors=colors,
#    3008         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# ...

# %%
import matplotlib.pyplot as plt
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 20.6, 8.8, 8, 7.7, 6.7]
#colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0','#ffb3e6']
explode = (0.1, 0, 0, 0, 0, 0)
plt.pie(popularity, explode=explode, labels=languages, autopct='%1.1f%%', shadow=True, startangle=140)
#plt.axis('equal')
plt.title('Popularity of Programming Languages')
plt.show()

# %%
import matplotlib.pyplot as plt
data = {'Java':22.2,'Python':17.6,'PHP':8.8,'JavaScript':8,'C#':7.7,'C++':6.7}
courses = list(data.keys())
values = list(data.values())
explode = (0.1, 0, 0, 0, 0, 0)
plt.pie(popularity, explode=explode, labels=languages,autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('Popularity of Programming Languages')
plt.show()

# %%
import pandas as pd
num = [1,2,3,4,5]
a=pd.Series(num)
dict = { "Vishnu":"devu","Athul":"dil","Akshay":"Three"}
print(a)
pd.Series(dict)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# Vishnu     devu
# Athul       dil
# Akshay    Three
# dtype: object

# %%
import pandas as pd
num = [1,2,3,4,5]
pd.Series(num)
b = { "vishnu":"devu",5:"dil",6:"Three"}
pd.Series(b)
print(b["vishnu"])
# Out:
# devu

# %%
import pandas as pd
graph = {"x":[1,2,3,4],"y":[5,6,7,8]}
pd.DataFrame(graph)
# Out:
#    x  y
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8
